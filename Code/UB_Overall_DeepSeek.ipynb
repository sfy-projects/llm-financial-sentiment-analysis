# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">1st Installing Necessary Libraries </span>

# %%
# !pip install PyMuPDF pandas openpyxl
# !pip install langchain
# !pip install langchain-community
# !pip install openai
# !pip install pandas openpyxl
# !pip install scipy scikit-learn
# !pip install seaborn
# !pip install fitz
# Out:
# Requirement already satisfied: PyMuPDF in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (1.26.3)
# Requirement already satisfied: pandas in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: openpyxl in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: langchain in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (0.3.26)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain) (0.3.69)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain-community in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (0.3.69)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (0.4.8)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=2.1.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-community) (2.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain-community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain-community) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: openai in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (1.97.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: pandas in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: openpyxl in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scipy in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (1.16.0)
# Requirement already satisfied: scikit-learn in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (1.7.1)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from scipy) (2.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: seaborn in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: fitz in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (0.0.1.dev2)
# Requirement already satisfied: configobj in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (5.0.9)
# Requirement already satisfied: configparser in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (7.2.0)
# Requirement already satisfied: httplib2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (0.22.0)
# Requirement already satisfied: nibabel in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (5.3.2)
# Requirement already satisfied: nipype in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (1.10.0)
# Requirement already satisfied: numpy in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (2.3.1)
# Requirement already satisfied: pandas in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (2.3.1)
# Requirement already satisfied: pyxnat in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (1.6.3)
# Requirement already satisfied: scipy in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from fitz) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from httplib2->fitz) (3.2.3)
# Requirement already satisfied: packaging>=20 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nibabel->fitz) (25.0)
# Requirement already satisfied: click>=6.6.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (8.2.1)
# Requirement already satisfied: networkx>=2.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (3.5)
# Requirement already satisfied: prov>=1.5.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (2.1.1)
# Requirement already satisfied: pydot>=1.2.3 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (4.0.1)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (2.9.0.post0)
# Requirement already satisfied: rdflib>=5.0.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (7.1.4)
# Requirement already satisfied: simplejson>=3.8.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (3.20.1)
# Requirement already satisfied: traits>=6.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (7.0.2)
# Requirement already satisfied: filelock>=3.0.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (3.18.0)
# Requirement already satisfied: acres in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (0.5.0)
# Requirement already satisfied: etelemetry>=0.3.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (0.3.1)
# Requirement already satisfied: looseversion!=1.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (1.3.0)
# Requirement already satisfied: puremagic in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from nipype->fitz) (1.30)
# Requirement already satisfied: requests in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from etelemetry>=0.3.1->nipype->fitz) (2.32.4)
# Requirement already satisfied: ci-info>=0.2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from etelemetry>=0.3.1->nipype->fitz) (0.3.0)
# Requirement already satisfied: six>=1.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from python-dateutil>=2.2->nipype->fitz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas->fitz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pandas->fitz) (2025.2)
# Requirement already satisfied: lxml>=4.3 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pyxnat->fitz) (6.0.0)
# Requirement already satisfied: pathlib>=1.0 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from pyxnat->fitz) (1.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dk/development/ALLDK/PROJECTS/StockSentimentAnalysis/.venv/lib/python3.13/site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (2025.7.14)

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">2nd Importing Key Libraries</span>

# %%
import fitz
import pandas as pd
import numpy as np
import re
import copy
from openai import OpenAI
import openai
import json
import time
import os
import pickle
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from scipy.stats import spearmanr
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">Function to extract paragraphs from PDF</span>

# %% [raw]
# def extract_text(pdf_path):
#     doc = fitz.open(pdf_path)
#     text = ""
#     for page in doc:
#         text += page.get_text()
#     return text
#
#
# def extract_clean_paragraphs(text):
#     # Split on double line breaks or visual separators
#     raw_paragraphs = re.split(r'\n\s*\n|[.]{5,}', text)
#
#     paragraphs = []
#     for p in raw_paragraphs:
#         clean_p = re.sub(r'\s+', ' ', p.strip())
#         if len(clean_p) > 30:
#             paragraphs.append(clean_p)
#     return paragraphs

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">Function to save paragraphs to an Excel file</span>

# %% [raw]
# def save_paragraphs_to_excel(paragraphs, output_path):
#     df = pd.DataFrame({
#         "Paragraph Number": list(range(1, len(paragraphs) + 1)),
#         "Paragraph Text": paragraphs
#     })
#     df.to_excel(output_path, index=False, engine="openpyxl")
#     print(f"Saved to: {output_path}")

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">Extract and save paragraphs from a PDF</span>

# %% [raw]
# pdf_path = "/Users/saraalyahya/Dissertation 🟠/Reports/Uber.pdf"
# output_path = "Paragraphs.xlsx"
#
# text = extract_text(pdf_path)
# paragraphs = extract_clean_paragraphs(text)
# save_paragraphs_to_excel(paragraphs, output_path)

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">Read the Human annotated exel file </span>

# %%
df_H = pd.read_excel('/Users/saraalyahya/Dissertation ✅/data/UB.xlsx', engine='openpyxl')

print(df_H.head())
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                 1  1-877-FACTSET www.callstreet.com Total Pages: ...
# 1                 2  06-Aug-2024 Uber Technologies, Inc. (UBER) Q2 ...
# 2                 3  Uber Technologies, Inc. (UBER) Q2 2024 Earning...
# 3                 4                   1-877-FACTSET www.callstreet.com
# 4                 5    2 Copyright © 2001-2024 FactSet CallStreet, LLC
#
#   Human Classification
# 0                    R
# 1                    R
# 2                    R
# 3                    R
# 4                    R

# %%
num_rows = df_H.shape[0]
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 1133

# %% [markdown]
# <span style="color:orange;font-weight: bold; font-size: 20px;">Relevance Classification: Human vs. LLM [Binary] </span>

# %%
# Convert multi-class sentiment labels to binary relevance
df_H["Relevance"] = df_H["Human Classification"].apply(lambda x: "Relevant" if x in [-2, -1, 0, +1, +2] else "Irrelevant")

# %%
df_H.head()
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                 1  1-877-FACTSET www.callstreet.com Total Pages: ...
# 1                 2  06-Aug-2024 Uber Technologies, Inc. (UBER) Q2 ...
# 2                 3  Uber Technologies, Inc. (UBER) Q2 2024 Earning...
# 3                 4                   1-877-FACTSET www.callstreet.com
# 4                 5    2 Copyright © 2001-2024 FactSet CallStreet, LLC
#
#   Human Classification   Relevance
# 0                    R  Irrelevant
# 1                    R  Irrelevant
# 2                    R  Irrelevant
# 3                    R  Irrelevant
# 4                    R  Irrelevant

# %%
# Stratified sampling: 10 relevant, 10 irrelevant
sample_relevant = df_H[df_H["Relevance"] == "Relevant"].sample(10, random_state=99)
sample_irrelevant = df_H[df_H["Relevance"] == "Irrelevant"].sample(10, random_state=99) # 99 so that each time i re-run the code it gives me the same 10 samples
df_demo = pd.concat([sample_relevant, sample_irrelevant])

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">----Open AI</span>

# %%
df_Empty = pd.read_excel('/Users/saraalyahya/Dissertation ✅/data/UB empty.xlsx', engine='openpyxl')

print(df_Empty.head())
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                 1  1-877-FACTSET www.callstreet.com Total Pages: ...
# 1                 2  06-Aug-2024 Uber Technologies, Inc. (UBER) Q2 ...
# 2                 3  Uber Technologies, Inc. (UBER) Q2 2024 Earning...
# 3                 4                   1-877-FACTSET www.callstreet.com
# 4                 5    2 Copyright © 2001-2024 FactSet CallStreet, LLC
#
#    Human Classification
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
num_rows = len(df_Empty)
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 1133

# %%
client = OpenAI(api_key="", base_url="") # I've removed the api key since it's the companies'

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">Binary Prompt</span>

# %%
def build_binary_relevance_prompt(text, demo_df):
    examples = ""
    for _, row in demo_df.iterrows():
        examples += f"Sentence: {row['Paragraph Text'].strip()}\nLabel: {row['Relevance']}\n\n"

    prompt = (
        "You are a financial assistant that classifies text as either Relevant or Irrelevant to financial sentiment.\n"
        "Here are some examples labeled by a human:\n\n"
        f"{examples}"
        "Now classify the following sentence.\n"
        f"Sentence: {text.strip()}\nLabel:"
    )
    return prompt

# %%
def classify_relevance_llm(row, demo_df):
    prompt_text = build_binary_relevance_prompt(row["Paragraph Text"], demo_df)

    try:
        response = client.chat.completions.create(
            # model="gpt-3.5-turbo",
            model="deepseek-chat",
            messages=[
                {"role": "system", "content": "You classify financial text as Relevant or Irrelevant."},
                {"role": "user", "content": prompt_text}
            ],
            max_tokens=3,
            temperature=1.5
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {e}"

# %%
df_llm_binary = pd.read_excel("/Users/saraalyahya/Dissertation ✅/data/UB empty.xlsx")

start_time = time.time()  # Start the timer

df_llm_binary["LLM Relevance"] = df_llm_binary.apply(lambda row: classify_relevance_llm(row, df_demo), axis=1)


end_time = time.time()  # End the timer

elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time:.2f} seconds")
# Out:
# Time taken: 4901.13 seconds

# %%
df_llm_binary.head(10)
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                 1  1-877-FACTSET www.callstreet.com Total Pages: ...
# 1                 2  06-Aug-2024 Uber Technologies, Inc. (UBER) Q2 ...
# 2                 3  Uber Technologies, Inc. (UBER) Q2 2024 Earning...
# 3                 4                   1-877-FACTSET www.callstreet.com
# 4                 5    2 Copyright © 2001-2024 FactSet CallStreet, LLC
# 5                 6  Deepa Subramanian Vice President, Investor Rel...
# 6                 7  Brian Nowak Analyst, Morgan Stanley & Co. LLC ...
# 7                 8  Operator: Hello, and welcome to the Uber Q2 20...
# 8                 9  I would now like to turn the conference over t...
# 9                10  Deepa Subramanian Vice President, Investor Rel...
#
#    Human Classification LLM Relevance
# 0                   NaN     Label: Ir
# 1                   NaN     Label: Ir
# 2                   NaN     Label: Ir
# 3                   NaN     Label: Ir
# 4                   NaN     Label: Ir
# 5                   NaN     Label: Ir
# 6                   NaN     Label: Ir
# 7                   NaN     Label: Ir
# 8                   NaN     Label: Ir
# 9                   NaN     Label: Ir

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">compare llm with human </span>

# %%
df_H.head()
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                 1  1-877-FACTSET www.callstreet.com Total Pages: ...
# 1                 2  06-Aug-2024 Uber Technologies, Inc. (UBER) Q2 ...
# 2                 3  Uber Technologies, Inc. (UBER) Q2 2024 Earning...
# 3                 4                   1-877-FACTSET www.callstreet.com
# 4                 5    2 Copyright © 2001-2024 FactSet CallStreet, LLC
#
#   Human Classification   Relevance
# 0                    R  Irrelevant
# 1                    R  Irrelevant
# 2                    R  Irrelevant
# 3                    R  Irrelevant
# 4                    R  Irrelevant

# %%
# Merge on Paragraph Number
df_B_merge= df_H.merge(df_llm_binary[["Paragraph Number", "LLM Relevance"]], on="Paragraph Number", how="inner")

# %%
df_B_merge.head()
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                 1  1-877-FACTSET www.callstreet.com Total Pages: ...
# 1                 2  06-Aug-2024 Uber Technologies, Inc. (UBER) Q2 ...
# 2                 3  Uber Technologies, Inc. (UBER) Q2 2024 Earning...
# 3                 4                   1-877-FACTSET www.callstreet.com
# 4                 5    2 Copyright © 2001-2024 FactSet CallStreet, LLC
#
#   Human Classification   Relevance LLM Relevance
# 0                    R  Irrelevant     Label: Ir
# 1                    R  Irrelevant     Label: Ir
# 2                    R  Irrelevant     Label: Ir
# 3                    R  Irrelevant     Label: Ir
# 4                    R  Irrelevant     Label: Ir

# %%
y_true = df_B_merge["Relevance"]
y_pred = df_B_merge["LLM Relevance"]

labels = ["Relevant", "Irrelevant"]
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap="Blues", values_format="d")
plt.title("Confusion Matrix: Human vs. LLM Relevance")
plt.show()

# %% [markdown]
# - the LLM correctly identified 727 sentences as Relevant, matching human judgment (True Positives)
#
# - the LLM correctly identified 176 sentences as Irrelevant (True Negatives)
#
# - the LLM incorrectly labeled 224 irrelevant sentences as Relevant (False Positives)
#
# - the LLM missed 6 relevant sentences, calling them Irrelevant (False Negatives)

# %%
# Clean string labels
y_true = [label.replace("Label: ", "").strip() for label in y_true]
y_pred = [label.replace("Label: ", "").strip() for label in y_pred]

# %%
print("Unique y_true labels:", set(y_true))
print("Unique y_pred labels:", set(y_pred))
# Out:
# Unique y_true labels: {'Relevant', 'Irrelevant'}
# Unique y_pred labels: {'Ir', 'Irrelevant', 'The sentence discusses', 'The label for', 'Relevant', 'The sentence "', 'The sentence is'}

# %%
#print(classification_report(y_true, y_pred, target_names=["Relevant", "Irrelevant"]))
print(classification_report(y_true,y_pred,labels=["Relevant", "Irrelevant"],target_names=["Relevant", "Irrelevant"], zero_division=0 ))
# Out:
#               precision    recall  f1-score   support
#
#     Relevant       0.96      0.92      0.94       733
#   Irrelevant       0.83      0.01      0.02       400
#
#    micro avg       0.96      0.60      0.74      1133
#    macro avg       0.90      0.46      0.48      1133
# weighted avg       0.92      0.60      0.62      1133

# %% [markdown]
# - 80% of the LLM's predictions match the human annotations
#
# Relevant Class:
#
#
# - Precision: 0.97 → When the LLM says a sentence is relevant, it's correct 97% of the time
#
# - Recall: 0.44 → It captures 44% of all human-labeled relevant sentences
#
# - F1 Score: 0.60 → Moderate performance; the LLM is precise but misses many relevant sentences
#
# Irrelevant Class:
#
# - Precision: 0.76 → When the LLM says a sentence is irrelevant, it's correct 76% of the time
#
# - Recall: 0.99 → It catches almost all irrelevant sentences
#
# - F1 Score: 0.86 → Strong performance; the LLM is confident and accurate here

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">Ive added this code so i can do a text comparison (manually) for my paper</span>

# %%
# False Positives
fp = df_B_merge[(df_B_merge["Relevance"] == "Irrelevant") & (df_B_merge["LLM Relevance"] == "Relevant")]

# False Negatives
fn = df_B_merge[(df_B_merge["Relevance"] == "Relevant") & (df_B_merge["LLM Relevance"] == "Irrelevant")]

# print(fp)
# print(fn)

# %%
fp.to_excel("overall_Binary_fp.xlsx")

# %%
fn.to_excel("overall_Binary_fn.xlsx")

# %% [markdown]
# <span style="color:orange;font-weight: bold; font-size: 20px;">Sentiment Classification: Human vs. LLM [Ordinal]</span>

# %%
# Only keep relevant sentiment classes (-2 to +2)
df_Relv = df_H[df_H["Human Classification"].isin([-2, -1, 0, 1, 2])]

# %%
df_Relv.head(2)
# Out:
#     Paragraph Number                                     Paragraph Text  \
# 16                17  Dara Khosrowshahi Chief Executive Officer & Di...
# 17                18  These are super strong results that we're prou...
#
#    Human Classification Relevance
# 16                    2  Relevant
# 17                    2  Relevant

# %%
# Take 5 examples per class
example_dict = {}
for label in [-2, -1, 0, 1, 2]:
    samples = df_Relv[df_Relv["Human Classification"] == label].sample(5, random_state=99)
    example_dict[label] = samples["Paragraph Text"].tolist()

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">Prompt</span>

# %%
def build_few_shot_prompt(text, example_dict):
    label_description = {
        -2: "Strongly Negative",
        -1: "Negative",
        0: "Neutral",
        1: "Positive",
        2: "Strongly Positive"
    }

    example_block = "Here are example paragraphs labeled by a human annotator:\n\n"
    for label, texts in example_dict.items():
        for t in texts:
            example_block += f"Sentence: {t.strip()}\nLabel: {label} ({label_description[label]})\n\n"

    classification_prompt = (
        f"{example_block}"
        "Now classify the sentiment of the following paragraph using one of these exact labels: -2, -1, 0, +1, +2.\n"
        "-2 = Strongly Negative\n"
        "-1 = Negative\n"
        " 0 = Neutral\n"
        "+1 = Positive\n"
        "+2 = Strongly Positive\n\n"
        "**Important Rules:**\n"
        "- Only return the numeric label: -2, -1, 0, +1, or +2.\n"
        "- Do not explain.\n\n"
        f"Paragraph: {text.strip()}\nLabel:"
    )

    return classification_prompt

# %%
def classify_ordinal_sentiment(row, example_dict):
    prompt = build_few_shot_prompt(row["Paragraph Text"], example_dict)

    try:
        response = client.chat.completions.create(
            #model="gpt-3.5-turbo",
            model="deepseek-chat",
            messages=[
                {"role": "system", "content": "You are a financial sentiment classifier. Use only human-labeled examples to make consistent predictions."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=5,
            temperature=1.5
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {e}"

# %%
def classify_ordinal_sentiment(row, example_dict):
    prompt = build_few_shot_prompt(row["Paragraph Text"], example_dict)

    try:
        response = client.chat.completions.create(
            #model="gpt-3.5-turbo",
            model="deepseek-chat",
            messages=[
                {"role": "system", "content": "You are a financial sentiment classifier. Use only human-labeled examples to make consistent predictions."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=5,
            temperature=1.5
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"Error: {e}"

# %%
###### takes aroud 28 mins

# %%
start_time = time.time()  # Start the timer

df_Empty["LLM Sentiment"] = df_Empty.apply(lambda row: classify_ordinal_sentiment(row, example_dict), axis=1)


end_time = time.time()  # End the timer

elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time:.2f} seconds")
# Out:
# Time taken: 4290.85 seconds

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;">compare llm with human </span>

# %%
df_O_merge = df_Relv.merge(df_Empty[["Paragraph Number", "LLM Sentiment"]], on="Paragraph Number", how="inner")

# %%
df_O_merge.head(10)
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                17  Dara Khosrowshahi Chief Executive Officer & Di...
# 1                18  These are super strong results that we're prou...
# 2                19  First, the strength of the consumer and how Ub...
# 3                20  Where the current macroeconomic fears material...
# 4                21  In fact, in Q2, the number of first-time consu...
# 5                22  We'll continue to drive consistent top line gr...
# 6                23  Second, autonomous. Put simply, Uber is unique...
# 7                24  We also know that a key factor in AV commercia...
# 8                27  Let's all say that Uber will be an indispensab...
# 9                30  Brian Nowak Analyst, Morgan Stanley & Co. LLC ...
#
#   Human Classification Relevance LLM Sentiment
# 0                    2  Relevant            +2
# 1                    2  Relevant            +2
# 2                    2  Relevant            +2
# 3                    1  Relevant            +1
# 4                    1  Relevant            +2
# 5                    1  Relevant             2
# 6                    0  Relevant             1
# 7                    0  Relevant             1
# 8                    1  Relevant            +1
# 9                    0  Relevant             0

# %%
num_rows = len(df_O_merge)
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 733

# %%
# to count total rows before dropping
total_rows = len(df_O_merge)

# to count how many rows are missing either in the human or LLM label
rows_with_missing = df_O_merge[["Human Classification", "LLM Sentiment"]].isna().any(axis=1).sum()

print(f"Total rows: {total_rows}")
print(f"Rows with missing values: {rows_with_missing}")
print(f"Rows remaining after drop: {total_rows - rows_with_missing}")
# Out:
# Total rows: 733
# Rows with missing values: 0
# Rows remaining after drop: 733

# %%
# to mack sure it's integers

# %%
df_O_merge["Human Classification"] = df_O_merge["Human Classification"].astype(int)
df_O_merge["LLM Sentiment"] = df_O_merge["LLM Sentiment"].astype(int)

# %%
df_O_merge.head()
# Out:
#    Paragraph Number                                     Paragraph Text  \
# 0                17  Dara Khosrowshahi Chief Executive Officer & Di...
# 1                18  These are super strong results that we're prou...
# 2                19  First, the strength of the consumer and how Ub...
# 3                20  Where the current macroeconomic fears material...
# 4                21  In fact, in Q2, the number of first-time consu...
#
#    Human Classification Relevance  LLM Sentiment
# 0                     2  Relevant              2
# 1                     2  Relevant              2
# 2                     2  Relevant              2
# 3                     1  Relevant              1
# 4                     1  Relevant              2

# %% [markdown]
# ### Evaluation

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;"> Metrics 1: Exact Match Accuracy </span>

# %%
# to extract the true and predicted labels
y_true = df_O_merge["Human Classification"]
y_pred = df_O_merge["LLM Sentiment"]

def exact_match_accuracy(y_true, y_pred):
    return (y_true == y_pred).mean()

# %%
# to calculate accuracy
exact_accuracy = exact_match_accuracy(y_true, y_pred)

# to display result
print(f" Exact Match Accuracy (excluding 'R'): {exact_accuracy:.2%}") # to convert it to a percentage and show 2 decimals
# Out:
#  Exact Match Accuracy (excluding 'R'): 56.62%

# %%
#this means that just below half the cases, LLM’s sentiment prediction matched my human label exactly

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;"> Metrics 2: MAE </span>

# %%
mae = mean_absolute_error(y_true, y_pred)
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 0.60

# %%
total_rows = len(df_O_merge)

print(f"Total rows: {total_rows}")
# Out:
# Total rows: 733

# %%
errors = abs(y_true - y_pred)

# Create bins
bins = np.arange(0, max(errors)+1.5, 0.5)

# ✅ Create the figure first
plt.figure(figsize=(6, 4))

# Plot the histogram and capture the counts and bin edges
counts, bin_edges, patches = plt.hist(errors, bins=bins, edgecolor='black', color='skyblue')

# Add labels
for count, edge in zip(counts, bin_edges[:-1]):
    if count > 0:
        plt.text(edge + 0.25, count + 1, str(int(count)), ha='center', fontsize=9)

# Plot settings
plt.title("Distribution of Absolute Errors")
plt.xlabel("Absolute Error")
plt.ylabel("Frequency")
plt.xticks(np.arange(0, max(errors)+1, 1))
plt.show()

# %% [markdown]
# - this chart shows how wrong the AI was compared to human labels
#
# - each bar tells us how many times the AI was off by a certain amount
#
# What each bar means:
#
# - 0: How many times AI was exactly right (where it predicted the same as the human) → 375 times
#
# - 1: AI was close, but off by 1 (for example: human's annotation was 0, it said +1) → 259 times
#
# - 2: AI was moderately off (for example: human's annotation was -1, it said +1) → 73 times
#
# - 3: AI was very off (for example: human's annotation was +2, it said -1) → 22 times
#
# - 4: AI was extremely off (for example: human's annotation was -2, it said +2) → 4 times

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;"> Metrics 3: Spearman Rank Correlation </span>

# %%
spearman_corr, _ = spearmanr(y_true, y_pred)
print(f"Spearman Rank Correlation: {spearman_corr:.2f}")
# Out:
# Spearman Rank Correlation: 0.62

# %% [markdown]
# - this means there's a moderate positive relationship between the AI's predictions and human annotations — when human annotations go up, the AI's prediction generally goes up too, but not consistently

# %%
# make sure y_true and y_pred are defined
y_true = df_O_merge["Human Classification"]
y_pred = df_O_merge["LLM Sentiment"]

# create the scatter + trend line plot
plt.figure(figsize=(6, 5))
sns.regplot(x=y_true, y=y_pred, ci=None, scatter_kws={'alpha': 0.6})
plt.title("Human vs. AI Sentiment Scores")
plt.xlabel("Human Label")
plt.ylabel("LLM Prediction")
plt.grid(True)
plt.show()

# %%
def exact_match_accuracy(y_true, y_pred):
    return (y_true == y_pred).mean()

print("Evaluation Summary (Relevant Only):")
print(f"Exact Match Accuracy:        {exact_match_accuracy(y_true, y_pred):.2%}")
print(f"Mean Absolute Error (MAE):   {mae:.2f}")
print(f"Spearman Rank Correlation:   {spearman_corr:.2f}")
# Out:
# Evaluation Summary (Relevant Only):
# Exact Match Accuracy:        56.62%
# Mean Absolute Error (MAE):   0.60
# Spearman Rank Correlation:   0.62

# %%
# exact matches
match = (y_true == y_pred)
match_counts = match.value_counts()


plt.figure(figsize=(5, 4))
plt.bar(['Match', 'Mismatch'], match_counts, color=['skyblue', 'pink'])
plt.title("Exact Match Accuracy")
plt.ylabel("Number of Predictions")
plt.show()

# %%
y_true = df_O_merge["Human Classification"]
y_pred = df_O_merge["LLM Sentiment"]

labels = [-2, -1, 0, 1, 2]
cm = confusion_matrix(y_true, y_pred, labels=labels)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix: Human vs. LLM Sentiment")
plt.show()

# %% [markdown]
# - row 1, column 2: 63 → Model predicted +2 instead of +1 (slight overestimation)
#
# - row 0, column 1: 44 → Model predicted +1 instead of 0 (moderate overestimation)
#
# - row 0, column 2: 21 → Model predicted +2 instead of 0 (strong overestimation)
#
# - row -1, column 1: 31 → Model predicted +1 instead of -1 (mild reversal)
#
# - row 2, column 1: 41 → Model predicted +1 instead of +2 (underestimation)
#
# - row 2, column 2: 70 → Model correctly predicted +2 when the human label was +2
#
# - row -2, column 0: 3 → Model correctly predicted -2
#
# - row -2, column 1: 22 → Model predicted -1 instead of -2 (mild underestimation)
#
# - row -2, column 2: 8 → Model predicted 0 instead of -2 (strong reversal)

# %%
# False Negatives: LLM underestimates sentiment
false_negatives = df_O_merge[df_O_merge["LLM Sentiment"] < df_O_merge["Human Classification"]]

# False Positives: LLM overestimates sentiment
false_positives = df_O_merge[df_O_merge["LLM Sentiment"] > df_O_merge["Human Classification"]]

# Display results
print(f"False Negatives (LLM underestimated sentiment): {len(false_negatives)}")
print(false_negatives[["Paragraph Number", "Paragraph Text", "Human Classification", "LLM Sentiment"]].head())

print("\nFalse Positives (LLM overestimated sentiment):", len(false_positives))
print(false_positives[["Paragraph Number", "Paragraph Text", "Human Classification", "LLM Sentiment"]].head())
# Out:
# False Negatives (LLM underestimated sentiment): 63
#     Paragraph Number                                     Paragraph Text  \
# 18                42  Prashanth Mahendra-Rajah Chief Financial Offic...
# 31                60  More recently, BYD has committed to very, very...
# 63               112  Dara Khosrowshahi Chief Executive Officer & Di...
# 81               138  I'd also say that when we look at the category...
# 86               143  And increasingly, we're working with merchants...
#
#     Human Classification  LLM Sentiment
# 18                     2              1
# 31                     2              1
# 63                     1              0
# 81                     1              0
# 86                     2              1
#
# False Positives (LLM overestimated sentiment): 255
#     Paragraph Number                                     Paragraph Text  \
# 4                 21  In fact, in Q2, the number of first-time consu...
# 5                 22  We'll continue to drive consistent top line gr...
# 6                 23  Second, autonomous. Put simply, Uber is unique...
# 7                 24  We also know that a key factor in AV commercia...
# 23                47  Dara Khosrowshahi Chief Executive Officer & Di...
#
#     Human Classification  LLM Sentiment
# 4                      1              2
# 5                      1              2
# 6                      0              1
# 7                      0              1
# 23                     0              1

# %%
false_negatives.to_excel("overall_Ordinal_fn.xlsx")

# %%
false_positives.to_excel("overall_Ordinal_fp.xlsx")

# %% [markdown]
# <span style="color:hotpink;font-weight: bold; font-size: 20px;"> Metrics 4: Per-Class Metrics </span>

# %%
print(classification_report(y_true, y_pred, labels=[-2, -1, 0, 1, 2]))
# Out:
#               precision    recall  f1-score   support
#
#           -2       0.86      0.13      0.22        47
#           -1       0.54      0.33      0.41       113
#            0       0.74      0.64      0.68       225
#            1       0.52      0.65      0.57       234
#            2       0.45      0.68      0.55       114
#
#     accuracy                           0.57       733
#    macro avg       0.62      0.48      0.49       733
# weighted avg       0.60      0.57      0.56       733

# %% [markdown]
# - overall Accuracy: 51% — the model correctly predicted sentiment in just over half the cases.
#
# Best performance:
#
# - Label 0 (neutral) had the highest precision (0.63) and recall (0.68), making it the most reliably predicted class.
#
#
# struggles most with extremes:
#
# - Label -2 (strongly negative) had very low recall (0.06), meaning the model rarely catches these cases.
#
# - Label -1 also showed weak performance across all metrics, with an F1-score of just 0.34.
#
# - Macro average F1-score is 0.42, showing weak performance across classes, especially the less frequent or more extreme sentiments.
#
# - Weighted average F1-score is 0.49, indicating that even with class imbalance, the overall effectiveness is limited.

# %%
# Create an empty dictionary to store the results
misclassifications = {}

# Loop through all possible combinations of true and predicted labels where they don't match
for true_label in [-2, -1, 0, 1, 2]:
    for pred_label in [-2, -1, 0, 1, 2]:
        if true_label != pred_label:
            key = f"True: {true_label}, Predicted: {pred_label}"
            filtered = df_O_merge[
                (df_O_merge["Human Classification"] == true_label) &
                (df_O_merge["LLM Sentiment"] == pred_label)
            ]
            misclassifications[key] = filtered

# Example: print a few key misclassifications
for key, df in misclassifications.items():
    print(f"\n{key} → {len(df)} samples")
    print(df[["Paragraph Number", "Paragraph Text", "Human Classification", "LLM Sentiment"]].head(3))
# Out:
# True: -2, Predicted: -1 → 19 samples
#      Paragraph Number                                     Paragraph Text  \
# 50                 91  Justin Post Analyst, BofA Securities, Inc. Q T...
# 119               237  So, overall, we're quite optimistic in terms o...
# 134               263  Your comment on sort of where is Mobility head...
#
#      Human Classification  LLM Sentiment
# 50                     -2             -1
# 119                    -2             -1
# 134                    -2             -1
#
# True: -2, Predicted: 0 → 6 samples
#      Paragraph Number                                     Paragraph Text  \
# 260               479  Dara Khosrowshahi Chief Executive Officer & Di...
# 281               509  In terms of AV, I think a couple of things in ...
# 282               510  The operational domain for many of these AV de...
#
#      Human Classification  LLM Sentiment
# 260                    -2              0
# 281                    -2              0
# 282                    -2              0
#
# True: -2, Predicted: 1 → 12 samples
#      Paragraph Number                                     Paragraph Text  \
# 53                 94  We might be seeing it. In some of the Western ...
# 112               225  We're looking at the density by quartile of al...
# 176               330  Typically, we look for behaviors that are freq...
#
#      Human Classification  LLM Sentiment
# 53                     -2              1
# 112                    -2              1
# 176                    -2              1
#
# True: -2, Predicted: 2 → 4 samples
#      Paragraph Number                                     Paragraph Text  \
# 462               759  Turning to our drawdown fund business: a few w...
# 554               889  One year ago, we said that real estate values ...
# 627               998  In closing, although the path ahead is now mor...
#
#      Human Classification  LLM Sentiment
# 462                    -2              2
# 554                    -2              2
# 627                    -2              2
#
# True: -1, Predicted: -2 → 1 samples
#      Paragraph Number                                     Paragraph Text  \
# 368               635  And, Mark, I just stress on the policy angle t...
#
#      Human Classification  LLM Sentiment
# 368                    -1             -2
#
# True: -1, Predicted: 0 → 28 samples
#     Paragraph Number                                     Paragraph Text  \
# 26                52  So I don't – AV is not something that we're go...
# 41                77  And then also on the Delivery side, we've seen...
# 72               126  John Colantuoni Analyst, Jefferies LLC Q Great...
#
#     Human Classification  LLM Sentiment
# 26                    -1              0
# 41                    -1              0
# 72                    -1              0
#
# True: -1, Predicted: 1 → 41 samples
#     Paragraph Number                                     Paragraph Text  \
# 29                58  So it's a very targeted segment that we're goi...
# 35                66  We've got great improvements in advertising. I...
# 54                95  So typically, what we see is improvement in dr...
#
#     Human Classification  LLM Sentiment
# 29                    -1              1
# 35                    -1              1
# 54                    -1              1
#
# True: -1, Predicted: 2 → 6 samples
#      Paragraph Number                                     Paragraph Text  \
# 47                 83  In terms of our portfolio. We had made the str...
# 200               392  The key takeaway is that while AV technology i...
# 453               750  Second - our strong returns are the direct res...
#
#      Human Classification  LLM Sentiment
# 47                     -1              2
# 200                    -1              2
# 453                    -1              2
#
# True: 0, Predicted: -2 → 0 samples
# Empty DataFrame
# Columns: [Paragraph Number, Paragraph Text, Human Classification, LLM Sentiment]
# Index: []
#
# True: 0, Predicted: -1 → 8 samples
#      Paragraph Number                                     Paragraph Text  \
# 163               309  So we are continuing to kind of grind if you w...
# 324               579  Dara Khosrowshahi Chief Executive Officer & Di...
# 357               620  Mark Mahaney Analyst, Evercore ISI Q Okay. Tha...
#
#      Human Classification  LLM Sentiment
# 163                     0             -1
# 324                     0             -1
# 357                     0             -1
#
# True: 0, Predicted: 1 → 55 samples
#     Paragraph Number                                     Paragraph Text  \
# 6                 23  Second, autonomous. Put simply, Uber is unique...
# 7                 24  We also know that a key factor in AV commercia...
# 23                47  Dara Khosrowshahi Chief Executive Officer & Di...
#
#     Human Classification  LLM Sentiment
# 6                      0              1
# 7                      0              1
# 23                     0              1
#
# True: 0, Predicted: 2 → 19 samples
#      Paragraph Number                                     Paragraph Text  \
# 157               300  And then question number two on frequency over...
# 169               321  Back in February, we also said liquidity was i...
# 244               455  Now, I think that you're going to see lots of ...
#
#      Human Classification  LLM Sentiment
# 157                     0              2
# 169                     0              2
# 244                     0              2
#
# True: 1, Predicted: -2 → 0 samples
# Empty DataFrame
# Columns: [Paragraph Number, Paragraph Text, Human Classification, LLM Sentiment]
# Index: []
#
# True: 1, Predicted: -1 → 4 samples
#      Paragraph Number                                     Paragraph Text  \
# 98                169  What that allows us to do is to pivot those in...
# 250               464  First, our guidance for the first quarter incl...
# 315               568  Dara Khosrowshahi Chief Executive Officer & Di...
#
#      Human Classification  LLM Sentiment
# 98                      1             -1
# 250                     1             -1
# 315                     1             -1
#
# True: 1, Predicted: 0 → 14 samples
#     Paragraph Number                                     Paragraph Text  \
# 63               112  Dara Khosrowshahi Chief Executive Officer & Di...
# 81               138  I'd also say that when we look at the category...
# 88               151  Ross Sandler Analyst, Barclays Capital, Inc. Q...
#
#     Human Classification  LLM Sentiment
# 63                     1              0
# 81                     1              0
# 88                     1              0
#
# True: 1, Predicted: 2 → 65 samples
#     Paragraph Number                                     Paragraph Text  \
# 4                 21  In fact, in Q2, the number of first-time consu...
# 5                 22  We'll continue to drive consistent top line gr...
# 33                64  Prashanth Mahendra-Rajah Chief Financial Offic...
#
#     Human Classification  LLM Sentiment
# 4                      1              2
# 5                      1              2
# 33                     1              2
#
# True: 2, Predicted: -2 → 0 samples
# Empty DataFrame
# Columns: [Paragraph Number, Paragraph Text, Human Classification, LLM Sentiment]
# Index: []
#
# True: 2, Predicted: -1 → 0 samples
# Empty DataFrame
# Columns: [Paragraph Number, Paragraph Text, Human Classification, LLM Sentiment]
# Index: []
#
# True: 2, Predicted: 0 → 2 samples
#      Paragraph Number                                     Paragraph Text  \
# 485               788   Adam Beatty: Great perspective, appreciate that.
# 719              1114  I think that positions us extremely well. But ...
#
#      Human Classification  LLM Sentiment
# 485                     2              0
# 719                     2              0
#
# True: 2, Predicted: 1 → 34 samples
#     Paragraph Number                                     Paragraph Text  \
# 18                42  Prashanth Mahendra-Rajah Chief Financial Offic...
# 31                60  More recently, BYD has committed to very, very...
# 86               143  And increasingly, we're working with merchants...
#
#     Human Classification  LLM Sentiment
# 18                     2              1
# 31                     2              1
# 86                     2              1

# %%
with pd.ExcelWriter("sentiment_misclassifications.xlsx") as writer:
    for key, df in misclassifications.items():
        # Sheet names can't be longer than 31 chars
        sheet_name = key.replace("True: ", "T").replace(", Predicted: ", "_P")
        df.to_excel(writer, sheet_name=sheet_name[:31], index=False)

# %%
import pandas as pd

# FALSE POSITIVES: LLM overestimated sentiment
false_pos = df_O_merge[df_O_merge["LLM Sentiment"] > df_O_merge["Human Classification"]]

# FALSE NEGATIVES: LLM underestimated sentiment
false_neg = df_O_merge[df_O_merge["LLM Sentiment"] < df_O_merge["Human Classification"]]

# Function to export misclassifications into an Excel file
def export_misclassifications(df, filename):
    with pd.ExcelWriter(filename) as writer:
        for true_label in [-2, -1, 0, 1, 2]:
            for pred_label in [-2, -1, 0, 1, 2]:
                if pred_label != true_label:
                    subset = df[
                        (df["Human Classification"] == true_label) &
                        (df["LLM Sentiment"] == pred_label)
                    ]
                    if len(subset) > 0:
                        sheet_name = f"T{true_label}_P{pred_label}"
                        subset.to_excel(writer, sheet_name=sheet_name[:31], index=False)

# Export to two separate Excel files
export_misclassifications(false_pos, "all_FP_Sentiment.xlsx")
export_misclassifications(false_neg, "all_FN_Sentiment.xlsx")
